# %%
import pandas as pd
import numpy as np
import json
import operator

# %%
pagerank_result = pd.read_csv('result.csv', names=['float_id','w'])
pagerank_result['id'] = pagerank_result['float_id'].apply(lambda x: int(x))
pagerank_result['rank'] = pagerank_result['w'].rank(method='min', ascending=False).apply(int)
pagerank_result
# Out:
#      float_id         w       id  rank
# 0   3817690.0  0.007610  3817690    64
# 1   3817652.0  0.007610  3817652    64
# 2   3817610.0  0.007610  3817610    64
# 3   2392748.0  0.007610  2392748    64
# 4   2939086.0  0.007610  2939086    64
# ..        ...       ...      ...   ...
# 80     2441.0  0.011765     2441    22
# 81     8351.0  0.011765     8351    22
# 82     3087.0  0.011765     3087    22
# 83     8349.0  0.011765     8349    22
# 84     2975.0  0.011765     2975    22
#
# [85 rows x 4 columns]

# %%
actors = pd.read_csv('actors.csv')
weight = pd.read_csv('popularity_weight.csv')
weight.rename(columns={"actor1": "source", "actor2": "target"}, inplace=True)
weight = weight[weight['source'].isin(pagerank_result['id']) & weight['target'].isin(pagerank_result['id'])]

weight['source'] = weight['source'].apply(str)
weight['target'] = weight['target'].apply(str)
weight
# Out:
#          source   target   weight
# 909          31       32  76.3210
# 910          31       33  51.2315
# 911          31       34  76.3210
# 912          31       35  76.3210
# 966          31     6751  76.3210
# ...         ...      ...      ...
# 623753  3817649  3817687  76.3210
# 623754  3817649  3817690  76.3210
# 623755  3817652  3817687  76.3210
# 623756  3817652  3817690  76.3210
# 623757  3817687  3817690  76.3210
#
# [753 rows x 3 columns]

# %%
data = pd.merge(actors, pagerank_result, on="id", how="inner")
data
# Out:
#     adult                                      also_known_as  \
# 0   False  ['Thomas Jeffrey Hanks', 'Том Хэнкс', 'توم هان...
# 1   False  ['Robin Wright-Penn', '로빈 라이트', 'Robin Virgini...
# 2   False                                 ['Gary A. Sinise']
# 3   False  ['Michael T. Williamson', 'Mykel T. Williamson...
# 4   False                                                 []
# ..    ...                                                ...
# 80  False                                                 []
# 81  False                                                 []
# 82  False                                                 []
# 83  False                                                 []
# 84  False                                                 []
#
#                                             biography    birthday    deathday  \
# 0   Thomas Jeffrey Hanks (born July 9, 1956) is an...  1956-07-09         NaN
# ...

# %%
web_data = {'nodes':[], 'links': weight.to_dict('records')}

for i, r in data.iterrows():
    web_data['nodes'].append({
        'id': str(r['id']),
        'color': 'cyan' if r['gender'] == 2 else 'pink',
        'size': 5*range(10,0,-1)[r['rank']-1] if r['rank'] <= 10 else 1,
        'popularity': int(r['popularity']),
        'label': r['name'],
        'rank' : r['rank'],
    })
web_data


with open("data.json", "w") as outfile:
    json.dump(web_data, outfile, indent=4)

# %%
print(list(range(22,0,-1))[21])
# Out:
# 1

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6d5d09ee-64f3-449d-b6a1-819961e8c97c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
